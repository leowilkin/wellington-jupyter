# %% [markdown]
# # Lesson 6 Extension

# %%
# 1 
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# Visualise the molecules you have drawn using their smiles strings.
#
# You did this in Lesson 1 by first creating a `mol` object using the `Chem.MolFromSmiles()` function
#
# Then using the `Draw.MolToImage()` function

# %%
# Smiles string for acetyl salicylic acid 'OC(=O)c1c(O)cccc1'
mol = Chem.MolFromSmiles('OC(=O)c1c(O)cccc1')
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x7FA370C21DC0>
